# %% [markdown]
# <a href="https://colab.research.google.com/github/kavy-sys/chapter/blob/master/Amazon_Price_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import smtplib
import time
import requests
from bs4 import BeautifulSoup

########ESSENTIAL THINGS##########
MY_EMAIL ="padala3roopa@gmail.com"
PASSWORD="aplf wjlg mkzc aouk"
URL="https://www.amazon.in/VAYA-Leak-Resistant-Containers-Lightweight-Portion-Control/dp/B0F7M17H8S/?_encoding=UTF8&pd_rd_w=KFEFJ&content-id=amzn1.sym.9ae57ac8-0a27-4217-ade0-a78be3c1bab0&pf_rd_p=9ae57ac8-0a27-4217-ade0-a78be3c1bab0&pf_rd_r=DQRCMJNKSWZ5GY6SF1WT&pd_rd_wg=v8cpP&pd_rd_r=9367cd0c-e560-45b1-9e5d-a3fc65e3357c&ref_=pd_hp_d_btf_LPDEALS&th=1"
TARGET_PRICE=800

##########NECESSARY TO PREVENT FROM BLOCKING BY ECOMMERCE WEBSITE###########
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/150.0.0.0 Safari/537.36"

}


def check_price():
  response=requests.get(URL,headers=headers)
  soup=BeautifulSoup(response.content,"html.parser")

  ######getting title and price by giving class and id names#########
  title=soup.find(id="productTitle").get_text().strip()
  check_price=soup.find(class_="a-price-whole").get_text().strip()
  print(title)
  print(check_price)

  price=int(check_price.replace(",",""))
  print(price)




check_price()

if check_price<800:
  with smtplib.SMTP("smtp.gmail.com") as connection:
    connection.starttls()
    connection.login(user=MY_EMAIL,password=PASSWORD)
    connection.sendmail(from_addr=MY_EMAIL,
                        to_addrs="padalaroopa@yahoo.com",
                        msg="it is working")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1761/4160199177.py in <cell line: 0>()
#      32
#      33
# ---> 34 check_price()
#      35
#      36 if check_price<800:
#
# /tmp/ipykernel_1761/4160199177.py in check_price()
#      21
#      22   ######getting title and price by giving class and id names#########
# ---> 23   title=soup.find(id="productTitle").get_text().strip()
#      24   check_price=soup.find(class_="a-price-whole").get_text().strip()
#      25   print(title)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
